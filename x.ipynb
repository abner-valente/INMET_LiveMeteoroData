# %%
from db_client import DBConfig, DBClient
import pandas as pd
from datetime import datetime, timedelta

##############################################################################
# Processo de conexão e inserção dos dados trataodos no BD 🎲
##############################################################################
create_tb = """
CREATE TABLE IF NOT EXISTS public.INMET_MS (
        id SERIAL PRIMARY KEY,
        data DATE NOT NULL,
        hora_utc INT NOT NULL,
        temp_c FLOAT,
        temp_max_c FLOAT,
        temp_min_c FLOAT,
        umid_pct FLOAT,
        umid_max_pct FLOAT,
        umid_min_pct FLOAT,
        pto_orvalho_c FLOAT,
        pto_orvalho_max_c FLOAT,
        pto_orvalho_min_c FLOAT,
        press_hpa FLOAT,
        press_max_hpa FLOAT,
        press_min_hpa FLOAT,
        vento_ms FLOAT,
        dir_vento_ms FLOAT,
        raj_vento_ms FLOAT,
        radiacao_kj_m2 FLOAT,
        chuva_mm FLOAT,
        cod_estacao VARCHAR(50) NOT NULL,
        vl_latitude FLOAT,
        vl_longitude FLOAT,
        data_insercao TIMESTAMP DEFAULT CURRENT_TIMESTAMP
    )
        """

df_bd = pd.read_csv(f'saida/INMET_MS_{(datetime.now() - timedelta(hours=2)).strftime("%H") + "00"}_UTC.csv', sep=";", encoding="utf-8")
df_bd["data"] = pd.to_datetime(df_bd["data"], format="%d/%m/%Y", errors="coerce").dt.date

df_bd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   data               61 non-null     object
#  1   hora_utc           61 non-null     int64
#  2   temp_c             60 non-null     float64
#  3   temp_max_c         60 non-null     float64
#  4   temp_min_c         60 non-null     float64
#  5   umid_pct           57 non-null     float64
#  6   umid_max_pct       57 non-null     float64
#  7   umid_min_pct       57 non-null     float64
#  8   pto_orvalho_c      57 non-null     float64
#  9   pto_orvalho_max_c  57 non-null     float64
#  10  pto_orvalho_min_c  57 non-null     float64
#  11  press_hpa          60 non-null     float64
#  12  press_max_hpa      60 non-null     float64
#  13  press_min_hpa      60 non-null     float64
#  14  vento_ms           55 non-null     float64
#  15  dir_vento_ms       56 non-null     float64
#  16  raj_vento_ms       55 non-null     float64
#  17  radiacao_kj_m2     60 non-null     float64
#  18  chuva_mm           59 non-null     float64
#  19  cod_estacao        61 non-null     object
#  20  vl_latitude        61 non-null     float64
#  21  vl_longitude       61 non-null     float64
# dtypes: float64(19), int64(1), object(2)
# memory usage: 10.6+ KB

# %%
pg_local = DBClient(DBConfig.from_env(prefix="LOCAL_POSTGRES"))

pg_local.criar_tabela_bd(table_name="inmet_ms_utc", create_sql=create_tb, schema="public")

pg_local.df_to_table(df_bd, table_name="inmet_ms_utc", schema="public")
