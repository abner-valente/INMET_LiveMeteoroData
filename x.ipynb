# %%
import json
from playwright.sync_api import sync_playwright

URL = "https://tempo.inmet.gov.br/TabelaEstacoes/"

# %%
x = 'CORUMBA_(FAZ._SAO_FRANCISCO)_(S725)'
striped = x.split('(')[2].split(')')[0]
print(striped)
# Out:
# S725
